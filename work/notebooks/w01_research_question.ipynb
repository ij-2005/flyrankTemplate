# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ij-2005/flyrankTemplate/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *I pick Lane 4: CTR / Engagement Opportunity Scoring.
# This lane is important because it highlights pages with high impressions but low clicks, giving me a clear way to improve metadata and engagement. It ties directly to user behavior and conversion optimization, which I want to explore further.
# I am very interested in how machine learning adapts to this.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *The decision my work improves is helping new or growing channels prioritize which pages need CTR or engagement fixes to gain more viewers and algorithm traction.
# Actors include the editor, the channel owner, or the content team.
# Actions involve updating titles, rewriting descriptions with stronger SEO keywords, and adjusting layouts to look formal and trustworthy for viewers.
# The cost of a wrong call is wasted effort, missed traffic, and little to no improvement in conversions or engagement.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

# Load the uploaded CSV
df = pd.read_csv("content_refresh_anonymized.csv")

# Peek at impressions, clicks, and CTR for 3 sample rows
df[['content_id', 'impressions_90d', 'clicks_90d', 'ctr']].head(3)
# Out:
#              content_id  impressions_90d  clicks_90d   ctr
# 0  content_304f48230142             3803          29  0.76
# 1  content_a1fb4e703a9e            15320           7  0.05
# 2  content_9aa793d4d895            12581          11  0.09

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *My work will be able to say the observed patterns, such as pages with high impressions but low clicks compared to pages with lower impressions but higher CTR.
# The directional insight is to improve metadata or page layout to raise CTR.
# Decision-support comes from ranking pages by how weak their CTR is, so editors and owners know where effort matters most.*
#
# *It will never claim that a specific change directly caused CTR to rise — it only observes correlations, which can vary depending on events of the year.
# It cannot forecast Google’s algorithm or guarantee that every recommendation will 100% work, since audience behavior always differs.
# Lastly, the system is purely a support tool: it helps theorize possible improvements, but the responsibility for outcomes remains with the editors and owners.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
